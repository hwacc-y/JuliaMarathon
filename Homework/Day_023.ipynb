# %% [markdown]
# # Julia 基礎圖表繪製: Plots 套件
#
# ## 作業 023：繪製 3D 函數
#
# 練習繪製 3D 函數：$z = x^2 - y^2$，$x$ 範圍於 $-5 \sim 5$，$y$ 範圍於 $-5 \sim 5$ 之間。（請完成以下程式碼）

# %%
using Plots
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1260

# %%
n = 1000
x = collect(Float16, range(-5,length=n,stop=5))
y = collect(Float16, range(-5,length=n,stop=5))
# Out:
# 1000-element Array{Float16,1}:
#  -5.0
#  -4.99
#  -4.98
#  -4.97
#  -4.96
#  -4.95
#  -4.94
#  -4.93
#  -4.918
#  -4.91
#  -4.9
#  -4.89
#  -4.88
#   ⋮
#   4.89
#   4.9
#   4.91
#   4.918
#   4.93
#   4.94
#   4.95
#   4.96
#   4.97
#   4.98
#   4.99
#   5.0

# %%
f(x,y) = ((x^2)-(y^2))
# Out:
# f (generic function with 1 method)

# %%
p = plot(x,y,f,st=surface)

# %%
@gif for i in range(0,stop=2π, length=100)
    p =plot(x,y,f,st=surface)
    plot!(p, camera=(15*cos(i),40))
end
